# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# **PREPROCESSING**

# %%
sensors_list = os.listdir('C:/Users/DELL/Downloads/Projekt uzupełniający_SDA/sensors_csv')
sensors_list
# Out:
# ['sensor01_air.csv',
#  'sensor01_izopropanol.csv',
#  'sensor01_water.csv',
#  'sensor02_air.csv',
#  'sensor02_izopropanol.csv',
#  'sensor02_water.csv',
#  'sensor03_air.csv',
#  'sensor03_izopropanol.csv',
#  'sensor03_water.csv',
#  'sensor04_air.csv',
#  'sensor04_izopropanol.csv',
#  'sensor04_water.csv',
#  'sensor05_air.csv',
#  'sensor05_izopropanol.csv',
#  'sensor05_water.csv',
#  'sensor06_air.csv',
#  'sensor06_izopropanol.csv',
#  'sensor06_water.csv',
#  'sensor07_air.csv',
#  'sensor07_izopropanol.csv',
#  'sensor07_water.csv',
#  'sensor08_air.csv',
#  'sensor08_izopropanol.csv',
#  'sensor08_water.csv',
#  'sensor09_air.csv',
#  'sensor09_izopropanol.csv',
#  'sensor09_water.csv',
#  'sensor10_air.csv',
#  'sensor10_izopropanol.csv',
#  'sensor10_water.csv']

# %%
 sensors = []

def all_sensors_preprocessing(list):
    for element in list:
        sensor_df = pd.read_csv(element, delimiter=',', header=None)
        sensors.append(sensor_df)
    return  type(sensors)

# %%
all_sensors_preprocessing(sensors_list)
# Out:
# list

# %%
len(sensors)
# Out:
# 30

# %%
s1_a = pd.DataFrame(sensors[0])
s1_i = pd.DataFrame(sensors[1])
s1_w = pd.DataFrame(sensors[2])

s2_a = pd.DataFrame(sensors[3])
s2_i = pd.DataFrame(sensors[4])
s2_w = pd.DataFrame(sensors[5])

s3_a = pd.DataFrame(sensors[6])
s3_i = pd.DataFrame(sensors[7])
s3_w = pd.DataFrame(sensors[8])

s4_a = pd.DataFrame(sensors[9])
s4_i = pd.DataFrame(sensors[10])
s4_w = pd.DataFrame(sensors[11])

s5_a = pd.DataFrame(sensors[12])
s5_i = pd.DataFrame(sensors[13])
s5_w = pd.DataFrame(sensors[14])

s6_a = pd.DataFrame(sensors[15])
s6_i = pd.DataFrame(sensors[16])
s6_w = pd.DataFrame(sensors[17])

s7_a = pd.DataFrame(sensors[18])
s7_i = pd.DataFrame(sensors[19])
s7_w = pd.DataFrame(sensors[20])

s8_a = pd.DataFrame(sensors[21])
s8_i = pd.DataFrame(sensors[22])
s8_w = pd.DataFrame(sensors[23])

s9_a = pd.DataFrame(sensors[24])
s9_i = pd.DataFrame(sensors[25])
s9_w = pd.DataFrame(sensors[26])

s10_a = pd.DataFrame(sensors[27])
s10_i = pd.DataFrame(sensors[28])
s10_w = pd.DataFrame(sensors[29])

# %%
df_list_to_rename = [s1_a, s1_i, s1_w, s2_a, s2_i, s2_w, s3_a, s3_i, s3_w, s4_a, s4_i, s4_w, s5_a, s5_i, s5_w, 
                    s6_a, s6_i, s6_w, s7_a, s7_i, s7_w, s8_a, s8_i, s8_w, s9_a, s9_i, s9_w, s10_a, s10_i, s10_w]

# %%
def rename_col_0(df_list):
    for element in df_list:
        element = element.rename(columns={0:'S'})
        
        
s1_a = s1_a.rename(columns={0:'S'})
s1_i = s1_i.rename(columns={0:'S'})
s1_w = s1_w.rename(columns={0:'S'})

s2_a = s2_a.rename(columns={0:'S'})
s2_i = s2_i.rename(columns={0:'S'})
s2_w = s2_w.rename(columns={0:'S'})

s3_a = s3_a.rename(columns={0:'S'})
s3_i = s3_i.rename(columns={0:'S'})
s3_w = s3_w.rename(columns={0:'S'})

s4_a = s4_a.rename(columns={0:'S'})
s4_i = s4_i.rename(columns={0:'S'})
s4_w = s4_w.rename(columns={0:'S'})

s5_a = s5_a.rename(columns={0:'S'})
s5_i = s5_i.rename(columns={0:'S'})
s5_w = s5_w.rename(columns={0:'S'})

s6_a = s6_a.rename(columns={0:'S'})
s6_i = s6_i.rename(columns={0:'S'})
s6_w = s6_w.rename(columns={0:'S'})

s7_a = s7_a.rename(columns={0:'S'})
s7_i = s7_i.rename(columns={0:'S'})
s7_w = s7_w.rename(columns={0:'S'})

s8_a = s8_a.rename(columns={0:'S'})
s8_i = s8_i.rename(columns={0:'S'})
s8_w = s8_w.rename(columns={0:'S'})

s9_a = s9_a.rename(columns={0:'S'})
s9_i = s9_i.rename(columns={0:'S'})
s9_w = s9_w.rename(columns={0:'S'})

s10_a = s10_a.rename(columns={0:'S'})
s10_i = s10_i.rename(columns={0:'S'})
s10_w = s10_w.rename(columns={0:'S'})

# %%
split_1a = s1_a['S'].str.split(',', n=1, expand=True)
split_1i = s1_i['S'].str.split(',', n=1, expand=True)
split_1w = s1_w['S'].str.split(',', n=1, expand=True)

split_2a = s2_a['S'].str.split(',', n=1, expand=True)
split_2i = s2_i['S'].str.split(',', n=1, expand=True)
split_2w = s2_w['S'].str.split(',', n=1, expand=True)

split_3a = s3_a['S'].str.split(',', n=1, expand=True)
split_3i = s3_i['S'].str.split(',', n=1, expand=True)
split_3w = s3_w['S'].str.split(',', n=1, expand=True)

split_4a = s4_a['S'].str.split(',', n=1, expand=True)
split_4i = s4_i['S'].str.split(',', n=1, expand=True)
split_4w = s4_w['S'].str.split(',', n=1, expand=True)

split_5a = s5_a['S'].str.split(',', n=1, expand=True)
split_5i = s5_i['S'].str.split(',', n=1, expand=True)
split_5w = s5_w['S'].str.split(',', n=1, expand=True)

split_6a = s6_a['S'].str.split(',', n=1, expand=True)
split_6i = s6_i['S'].str.split(',', n=1, expand=True)
split_6w = s6_w['S'].str.split(',', n=1, expand=True)

split_7a = s7_a['S'].str.split(',', n=1, expand=True)
split_7i = s7_i['S'].str.split(',', n=1, expand=True)
split_7w = s7_w['S'].str.split(',', n=1, expand=True)

split_8a = s8_a['S'].str.split(',', n=1, expand=True)
split_8i = s8_i['S'].str.split(',', n=1, expand=True)
split_8w = s8_w['S'].str.split(',', n=1, expand=True)

split_9a = s9_a['S'].str.split(',', n=1, expand=True)
split_9i = s9_i['S'].str.split(',', n=1, expand=True)
split_9w = s9_w['S'].str.split(',', n=1, expand=True)

split_10a = s10_a['S'].str.split(',', n=1, expand=True)
split_10i = s10_i['S'].str.split(',', n=1, expand=True)
split_10w = s10_w['S'].str.split(',', n=1, expand=True)

# %%
s1_a['wavelength'] = split_1a[0]
s1_a['amplitude_1a'] = split_1a[1]
s1_a.drop('S', axis=1, inplace=True)
s1_i['wavelength'] = split_1i[0]
s1_i['amplitude_1i'] = split_1i[1]
s1_i.drop('S', axis=1, inplace=True)
s1_w['wavelength'] = split_1w[0]
s1_w['amplitude_1w'] = split_1w[1]
s1_w.drop('S', axis=1, inplace=True)

# %%
s2_a['wavelength'] = split_2a[0]
s2_a['amplitude_2a'] = split_2a[1]
s2_a.drop('S', axis=1, inplace=True)
s2_i['wavelength'] = split_2i[0]
s2_i['amplitude_2i'] = split_2i[1]
s2_i.drop('S', axis=1, inplace=True)
s2_w['wavelength'] = split_2w[0]
s2_w['amplitude_2w'] = split_2w[1]
s2_w.drop('S', axis=1, inplace=True)

# %%
s3_a['wavelength'] = split_3a[0]
s3_a['amplitude_3a'] = split_3a[1]
s3_a.drop('S', axis=1, inplace=True)
s3_i['wavelength'] = split_3i[0]
s3_i['amplitude_3i'] = split_3i[1]
s3_i.drop('S', axis=1, inplace=True)
s3_w['wavelength'] = split_3w[0]
s3_w['amplitude_3w'] = split_3w[1]
s3_w.drop('S', axis=1, inplace=True)

# %%
s4_a['wavelength'] = split_4a[0]
s4_a['amplitude_4a'] = split_4a[1]
s4_a.drop('S', axis=1, inplace=True)
s4_i['wavelength'] = split_4i[0]
s4_i['amplitude_4i'] = split_4i[1]
s4_i.drop('S', axis=1, inplace=True)
s4_w['wavelength'] = split_4w[0]
s4_w['amplitude_4w'] = split_4w[1]
s4_w.drop('S', axis=1, inplace=True)

# %%
s5_a['wavelength'] = split_5a[0]
s5_a['amplitude_5a'] = split_5a[1]
s5_a.drop('S', axis=1, inplace=True)
s5_i['wavelength'] = split_5i[0]
s5_i['amplitude_5i'] = split_5i[1]
s5_i.drop('S', axis=1, inplace=True)
s5_w['wavelength'] = split_5w[0]
s5_w['amplitude_5w'] = split_5w[1]
s5_w.drop('S', axis=1, inplace=True)

# %%
s6_a['wavelength'] = split_6a[0]
s6_a['amplitude_6a'] = split_6a[1]
s6_a.drop('S', axis=1, inplace=True)
s6_i['wavelength'] = split_6i[0]
s6_i['amplitude_6i'] = split_6i[1]
s6_i.drop('S', axis=1, inplace=True)
s6_w['wavelength'] = split_6w[0]
s6_w['amplitude_6w'] = split_6w[1]
s6_w.drop('S', axis=1, inplace=True)

# %%
s7_a['wavelength'] = split_7a[0]
s7_a['amplitude_7a'] = split_7a[1]
s7_a.drop('S', axis=1, inplace=True)
s7_i['wavelength'] = split_7i[0]
s7_i['amplitude_7i'] = split_7i[1]
s7_i.drop('S', axis=1, inplace=True)
s7_w['wavelength'] = split_7w[0]
s7_w['amplitude_7w'] = split_7w[1]
s7_w.drop('S', axis=1, inplace=True)

# %%
s8_a['wavelength'] = split_8a[0]
s8_a['amplitude_8a'] = split_8a[1]
s8_a.drop('S', axis=1, inplace=True)
s8_i['wavelength'] = split_8i[0]
s8_i['amplitude_8i'] = split_8i[1]
s8_i.drop('S', axis=1, inplace=True)
s8_w['wavelength'] = split_8w[0]
s8_w['amplitude_8w'] = split_8w[1]
s8_w.drop('S', axis=1, inplace=True)

# %%
s9_a['wavelength'] = split_9a[0]
s9_a['amplitude_9a'] = split_9a[1]
s9_a.drop('S', axis=1, inplace=True)
s9_i['wavelength'] = split_9i[0]
s9_i['amplitude_9i'] = split_9i[1]
s9_i.drop('S', axis=1, inplace=True)
s9_w['wavelength'] = split_9w[0]
s9_w['amplitude_9w'] = split_9w[1]
s9_w.drop('S', axis=1, inplace=True)

# %%
s10_a['wavelength'] = split_10a[0]
s10_a['amplitude_10a'] = split_10a[1]
s10_a.drop('S', axis=1, inplace=True)
s10_i['wavelength'] = split_10i[0]
s10_i['amplitude_10i'] = split_10i[1]
s10_i.drop('S', axis=1, inplace=True)
s10_w['wavelength'] = split_10w[0]
s10_w['amplitude_10w'] = split_10w[1]
s10_w.drop('S', axis=1, inplace=True)

# %%
s10_w.head()
# Out:
#    wavelength amplitude_10w
# 0    1.35e-06        8.3966
# 1  1.3501e-06        8.5327
# 2  1.3502e-06        8.4086
# 3  1.3503e-06        8.4676
# 4  1.3504e-06        8.3277

# %%
s1 = pd.merge(s1_a, s1_i, on='wavelength', how='outer')
s1 = pd.merge(s1, s1_w, on='wavelength', how='outer')

s2 = pd.merge(s2_a, s2_i, on='wavelength', how='outer')
s2 = pd.merge(s2, s2_w, on='wavelength', how='outer')

s3 = pd.merge(s3_a, s3_i, on='wavelength', how='outer')
s3 = pd.merge(s3, s3_w, on='wavelength', how='outer')

s4 = pd.merge(s4_a, s4_i, on='wavelength', how='outer')
s4 = pd.merge(s4, s4_w, on='wavelength', how='outer')

s5 = pd.merge(s5_a, s5_i, on='wavelength', how='outer')
s5 = pd.merge(s5, s5_w, on='wavelength', how='outer')

s6 = pd.merge(s6_a, s6_i, on='wavelength', how='outer')
s6 = pd.merge(s6, s6_w, on='wavelength', how='outer')

s7 = pd.merge(s7_a, s7_i, on='wavelength', how='outer')
s7 = pd.merge(s7, s7_w, on='wavelength', how='outer')

s8 = pd.merge(s8_a, s8_i, on='wavelength', how='outer')
s8 = pd.merge(s8, s8_w, on='wavelength', how='outer')

s9 = pd.merge(s9_a, s9_i, on='wavelength', how='outer')
s9 = pd.merge(s9, s9_w, on='wavelength', how='outer')

s10 = pd.merge(s10_a, s10_i, on='wavelength', how='outer')
s10 = pd.merge(s10, s10_w, on='wavelength', how='outer')

# %%
s1.head()
# Out:
#    wavelength amplitude_1a amplitude_1i amplitude_1w
# 0    1.35e-06       9.1792       8.5551        8.357
# 1  1.3501e-06       9.2003        8.675       8.4287
# 2  1.3502e-06       9.1968       8.7116       8.4422
# 3  1.3503e-06       9.1028       8.7157       8.4144
# 4  1.3504e-06       9.0601       8.6792       8.4034

# %%
df_to_numeric_list = [s1, s2, s3, s4, s5,
                      s6, s7, s8, s9, s10]

# %%
def numeric_to(list):
    for element in list:
        element['wavelength'] = pd.to_numeric(element['wavelength'])

s1['wavelength'] = pd.to_numeric(s1['wavelength'])
s2['wavelength'] = pd.to_numeric(s2['wavelength'])
s3['wavelength'] = pd.to_numeric(s3['wavelength'])
s4['wavelength'] = pd.to_numeric(s4['wavelength'])
s5['wavelength'] = pd.to_numeric(s5['wavelength'])
s6['wavelength'] = pd.to_numeric(s6['wavelength'])
s7['wavelength'] = pd.to_numeric(s7['wavelength'])
s8['wavelength'] = pd.to_numeric(s8['wavelength'])
s9['wavelength'] = pd.to_numeric(s9['wavelength'])
s10['wavelength'] = pd.to_numeric(s10['wavelength'])
s10.head()
# Out:
#    wavelength amplitude_10a amplitude_10i amplitude_10w
# 0    0.000001        9.2124         8.703        8.3966
# 1    0.000001        9.2734        8.7322        8.5327
# 2    0.000001        9.1703        8.6748        8.4086
# 3    0.000001        9.2478        8.5932        8.4676
# 4    0.000001        9.0771        8.5665        8.3277

# %%
def reduce_by_division(list):
    for element in list:
        element['wavelength'] = element['wavelength'].apply(lambda x: (x/(1e-6))*(10**3))

s1['wavelength'] = s1['wavelength'].apply(lambda x: (x/(1e-6))*(10**3))
s2['wavelength'] = s2['wavelength'].apply(lambda x: (x/(1e-6))*(10**3))
s3['wavelength'] = s3['wavelength'].apply(lambda x: (x/(1e-6))*(10**3))
s4['wavelength'] = s4['wavelength'].apply(lambda x: (x/(1e-6))*(10**3))
s5['wavelength'] = s5['wavelength'].apply(lambda x: (x/(1e-6))*(10**3))
s6['wavelength'] = s6['wavelength'].apply(lambda x: (x/(1e-6))*(10**3))
s7['wavelength'] = s7['wavelength'].apply(lambda x: (x/(1e-6))*(10**3))
s8['wavelength'] = s8['wavelength'].apply(lambda x: (x/(1e-6))*(10**3))
s9['wavelength'] = s9['wavelength'].apply(lambda x: (x/(1e-6))*(10**3))
s10['wavelength'] = s10['wavelength'].apply(lambda x: (x/(1e-6))*(10**3))

# %%
s1.head()
# Out:
#    wavelength amplitude_1a amplitude_1i amplitude_1w
# 0      1350.0       9.1792       8.5551        8.357
# 1      1350.1       9.2003        8.675       8.4287
# 2      1350.2       9.1968       8.7116       8.4422
# 3      1350.3       9.1028       8.7157       8.4144
# 4      1350.4       9.0601       8.6792       8.4034

# %%
all_sensors = pd.merge(s1, s2, on='wavelength', how='outer')
all_sensors = pd.merge(all_sensors, s3, on='wavelength', how='outer')
all_sensors = pd.merge(all_sensors, s4, on='wavelength', how='outer')
all_sensors = pd.merge(all_sensors, s5, on='wavelength', how='outer')
all_sensors = pd.merge(all_sensors, s6, on='wavelength', how='outer')
all_sensors = pd.merge(all_sensors, s7, on='wavelength', how='outer')
all_sensors = pd.merge(all_sensors, s8, on='wavelength', how='outer')
all_sensors = pd.merge(all_sensors, s9, on='wavelength', how='outer')
all_sensors = pd.merge(all_sensors, s10, on='wavelength', how='outer')
all_sensors.head()
# Out:
#    wavelength amplitude_1a amplitude_1i amplitude_1w amplitude_2a  \
# 0      1350.0       9.1792       8.5551        8.357       9.7793
# 1      1350.1       9.2003        8.675       8.4287       9.8643
# 2      1350.2       9.1968       8.7116       8.4422       9.8031
# 3      1350.3       9.1028       8.7157       8.4144        9.732
# 4      1350.4       9.0601       8.6792       8.4034       9.6895
#
#   amplitude_2i amplitude_2w amplitude_3a amplitude_3i amplitude_3w  ...  \
# 0       9.2544       9.0607       7.8831       7.3432       7.2354  ...
# 1       9.3012       9.1238       8.0971       7.4798        7.352  ...
# 2       9.2512       9.1159       7.9478        7.481       7.3746  ...
# 3       9.2734       9.0431       7.9979       7.4719        7.281  ...
# 4       9.1999        8.986        7.922        7.333       7.0982  ...
#
#   amplitude_7w amplitude_8a amplitude_8i amplitude_8w amplitude_9a  \
# ...

# %%
all_sensors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3001 entries, 0 to 3000
# Data columns (total 31 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   wavelength     3001 non-null   float64
#  1   amplitude_1a   3001 non-null   object
#  2   amplitude_1i   3001 non-null   object
#  3   amplitude_1w   3001 non-null   object
#  4   amplitude_2a   3001 non-null   object
#  5   amplitude_2i   3001 non-null   object
#  6   amplitude_2w   3001 non-null   object
#  7   amplitude_3a   3001 non-null   object
#  8   amplitude_3i   3001 non-null   object
#  9   amplitude_3w   3001 non-null   object
#  10  amplitude_4a   3001 non-null   object
#  11  amplitude_4i   3001 non-null   object
#  12  amplitude_4w   3001 non-null   object
#  13  amplitude_5a   3001 non-null   object
#  14  amplitude_5i   3001 non-null   object
#  15  amplitude_5w   3001 non-null   object
#  16  amplitude_6a   3001 non-null   object
# ...

# %%
sensors_a = all_sensors[['wavelength', 'amplitude_1a', 'amplitude_2a', 'amplitude_3a', 'amplitude_4a',
                        'amplitude_5a', 'amplitude_6a', 'amplitude_7a', 'amplitude_8a', 'amplitude_9a', 
                        'amplitude_10a']]

sensors_w = all_sensors[['wavelength', 'amplitude_1w', 'amplitude_2w', 'amplitude_3w', 'amplitude_4w',
                        'amplitude_5w', 'amplitude_6w', 'amplitude_7w', 'amplitude_8w', 'amplitude_9w', 
                        'amplitude_10w']]

sensors_i = all_sensors[['wavelength', 'amplitude_1i', 'amplitude_2i', 'amplitude_3i', 'amplitude_4i',
                        'amplitude_5i', 'amplitude_6i', 'amplitude_7i', 'amplitude_8i', 'amplitude_9i', 
                        'amplitude_10i']]

# %%
sensors_a['wavelength'] = sensors_a['wavelength'].apply(lambda x: (x/(1e+12))*(10**3))
sensors_w['wavelength'] = sensors_w['wavelength'].apply(lambda x: (x/(1e+12))*(10**3))
sensors_i['wavelength'] = sensors_i['wavelength'].apply(lambda x: (x/(1e+12))*(10**3))
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_1560\1638741463.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sensors_a['wavelength'] = sensors_a['wavelength'].apply(lambda x: (x/(1e+12))*(10**3))
# C:\Users\DELL\AppData\Local\Temp\ipykernel_1560\1638741463.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sensors_w['wavelength'] = sensors_w['wavelength'].apply(lambda x: (x/(1e+12))*(10**3))
# C:\Users\DELL\AppData\Local\Temp\ipykernel_1560\1638741463.py:3: SettingWithCopyWarning:
# ...

# %%
sensors_i.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3001 entries, 0 to 3000
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   wavelength     3001 non-null   float64
#  1   amplitude_1i   3001 non-null   object
#  2   amplitude_2i   3001 non-null   object
#  3   amplitude_3i   3001 non-null   object
#  4   amplitude_4i   3001 non-null   object
#  5   amplitude_5i   3001 non-null   object
#  6   amplitude_6i   3001 non-null   object
#  7   amplitude_7i   3001 non-null   object
#  8   amplitude_8i   3001 non-null   object
#  9   amplitude_9i   3001 non-null   object
#  10  amplitude_10i  3001 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 281.3+ KB

# %%
def change_dtypes(df):
    for column in df.columns:
        if df[column].dtypes == 'object':
            df[column] = df[column].astype('float')

# %%
change_dtypes(sensors_a)
change_dtypes(sensors_w)
change_dtypes(sensors_i)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_1560\1227267144.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('float')

# %%
sensors_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3001 entries, 0 to 3000
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   wavelength     3001 non-null   float64
#  1   amplitude_1a   3001 non-null   float64
#  2   amplitude_2a   3001 non-null   float64
#  3   amplitude_3a   3001 non-null   float64
#  4   amplitude_4a   3001 non-null   float64
#  5   amplitude_5a   3001 non-null   float64
#  6   amplitude_6a   3001 non-null   float64
#  7   amplitude_7a   3001 non-null   float64
#  8   amplitude_8a   3001 non-null   float64
#  9   amplitude_9a   3001 non-null   float64
#  10  amplitude_10a  3001 non-null   float64
# dtypes: float64(11)
# memory usage: 281.3 KB

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(sensors_a['wavelength'], sensors_a['amplitude_1a'], label='1a')
ax.plot(sensors_w['wavelength'], sensors_w['amplitude_1w'], label='1w')
ax.plot(sensors_i['wavelength'], sensors_i['amplitude_1i'], label='1i')

ax.plot(sensors_a['wavelength'], sensors_a['amplitude_2a'], label='2a')
ax.plot(sensors_w['wavelength'], sensors_w['amplitude_2w'], label='2w')
ax.plot(sensors_i['wavelength'], sensors_i['amplitude_2i'], label='2i')

ax.plot(sensors_a['wavelength'], sensors_a['amplitude_3a'], label='3a')
ax.plot(sensors_w['wavelength'], sensors_w['amplitude_3w'], label='3w')
ax.plot(sensors_i['wavelength'], sensors_i['amplitude_3i'], label='3i')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(sensors_a['wavelength'], sensors_a['amplitude_4a'], label='4a')
ax.plot(sensors_w['wavelength'], sensors_w['amplitude_4w'], label='4w')
ax.plot(sensors_i['wavelength'], sensors_i['amplitude_4i'], label='4i')

ax.plot(sensors_a['wavelength'], sensors_a['amplitude_5a'], label='5a')
ax.plot(sensors_w['wavelength'], sensors_w['amplitude_5w'], label='5w')
ax.plot(sensors_i['wavelength'], sensors_i['amplitude_5i'], label='5i')

ax.plot(sensors_a['wavelength'], sensors_a['amplitude_6a'], label='6a')
ax.plot(sensors_w['wavelength'], sensors_w['amplitude_6w'], label='6w')
ax.plot(sensors_i['wavelength'], sensors_i['amplitude_6i'], label='6i')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(sensors_a['wavelength'], sensors_a['amplitude_7a'], label='7a')
ax.plot(sensors_w['wavelength'], sensors_w['amplitude_7w'], label='7w')
ax.plot(sensors_i['wavelength'], sensors_i['amplitude_7i'], label='7i')

ax.plot(sensors_a['wavelength'], sensors_a['amplitude_8a'], label='8a')
ax.plot(sensors_w['wavelength'], sensors_w['amplitude_8w'], label='8w')
ax.plot(sensors_i['wavelength'], sensors_i['amplitude_8i'], label='8i')

ax.plot(sensors_a['wavelength'], sensors_a['amplitude_9a'], label='9a')
ax.plot(sensors_w['wavelength'], sensors_w['amplitude_9w'], label='9w')
ax.plot(sensors_i['wavelength'], sensors_i['amplitude_9i'], label='9i')

ax.plot(sensors_a['wavelength'], sensors_a['amplitude_10a'], label='10a')
ax.plot(sensors_w['wavelength'], sensors_w['amplitude_10w'], label='10w')
ax.plot(sensors_i['wavelength'], sensors_i['amplitude_10i'], label='10i')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(sensors_a['wavelength'], sensors_a['amplitude_1a'], label='1a')
ax.plot(sensors_a['wavelength'], sensors_a['amplitude_2a'], label='2a')
ax.plot(sensors_a['wavelength'], sensors_a['amplitude_3a'], label='3a')
ax.plot(sensors_a['wavelength'], sensors_a['amplitude_4a'], label='4a')
ax.plot(sensors_a['wavelength'], sensors_a['amplitude_5a'], label='5a')
ax.plot(sensors_a['wavelength'], sensors_a['amplitude_6a'], label='6a')
ax.plot(sensors_a['wavelength'], sensors_a['amplitude_7a'], label='7a')
ax.plot(sensors_a['wavelength'], sensors_a['amplitude_8a'], label='8a')
ax.plot(sensors_a['wavelength'], sensors_a['amplitude_9a'], label='9a')
ax.plot(sensors_a['wavelength'], sensors_a['amplitude_10a'], label='10a')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sc_aa = pd.DataFrame(pd.concat([s1_a['amplitude_1a'], s2_a['amplitude_2a'], s3_a['amplitude_3a'], s4_a['amplitude_4a'], s5_a['amplitude_5a'], s6_a['amplitude_6a'],
                  s7_a['amplitude_7a'],s8_a['amplitude_8a'], s9_a['amplitude_9a'], s10_a['amplitude_10a']], axis=0, ignore_index=True))
sc_aa.head()
# Out:
#         0
# 0  9.1792
# 1  9.2003
# 2  9.1968
# 3  9.1028
# 4  9.0601

# %%
sc_w = pd.DataFrame(pd.concat([s1_a['wavelength'], s2_a['wavelength'], s3_a['wavelength'], s4_a['wavelength'], s5_a['wavelength'], s6_a['wavelength'],
                  s7_a['wavelength'],s8_a['wavelength'], s9_a['wavelength'], s10_a['wavelength']], axis=0, ignore_index=True))
sc_w['wavelength'] = pd.to_numeric(sc_w['wavelength'])
sc_w['wavelength'] = sc_w['wavelength'].apply(lambda x: (x/(1e-6))*(10**3))
sc_w.head()
# Out:
#    wavelength
# 0      1350.0
# 1      1350.1
# 2      1350.2
# 3      1350.3
# 4      1350.4

# %%
sc_aa.insert(0, 'wavelength', sc_w['wavelength'])
sc_aa.head()
# Out:
#    wavelength       0
# 0      1350.0  9.1792
# 1      1350.1  9.2003
# 2      1350.2  9.1968
# 3      1350.3  9.1028
# 4      1350.4  9.0601

# %%
sc_aa = sc_aa.rename(columns={0:'amplitude_a'})
sc_aa.head()
# Out:
#    wavelength amplitude_a
# 0      1350.0      9.1792
# 1      1350.1      9.2003
# 2      1350.2      9.1968
# 3      1350.3      9.1028
# 4      1350.4      9.0601

# %%
sc_aw = pd.DataFrame(pd.concat([s1_w['amplitude_1w'], s2_w['amplitude_2w'], s3_w['amplitude_3w'], s4_w['amplitude_4w'], s5_w['amplitude_5w'], s6_w['amplitude_6w'],
                  s7_w['amplitude_7w'],s8_w['amplitude_8w'], s9_w['amplitude_9w'], s10_w['amplitude_10w']], axis=0, ignore_index=True))
sc_aw = sc_aw.rename(columns={0:'amplitude_w'})
sc_aw.insert(0, 'wavelength', sc_w['wavelength'])
sc_aw.head()
# Out:
#    wavelength amplitude_w
# 0      1350.0       8.357
# 1      1350.1      8.4287
# 2      1350.2      8.4422
# 3      1350.3      8.4144
# 4      1350.4      8.4034

# %%
sc_aw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30010 entries, 0 to 30009
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   wavelength   30010 non-null  float64
#  1   amplitude_w  30010 non-null  object
# dtypes: float64(1), object(1)
# memory usage: 469.0+ KB

# %%
sc_ai = pd.DataFrame(pd.concat([s1_i['amplitude_1i'], s2_i['amplitude_2i'], s3_i['amplitude_3i'], s4_i['amplitude_4i'], s5_i['amplitude_5i'], s6_i['amplitude_6i'],
                  s7_i['amplitude_7i'],s8_i['amplitude_8i'], s9_i['amplitude_9i'], s10_i['amplitude_10i']], axis=0, ignore_index=True))
sc_ai = sc_ai.rename(columns={0:'amplitude_i'})
sc_ai.insert(0, 'wavelength', sc_w['wavelength'])
sc_ai.head()
# Out:
#    wavelength amplitude_i
# 0      1350.0      8.5551
# 1      1350.1       8.675
# 2      1350.2      8.7116
# 3      1350.3      8.7157
# 4      1350.4      8.6792

# %%
sc_ai.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30010 entries, 0 to 30009
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   wavelength   30010 non-null  float64
#  1   amplitude_i  30010 non-null  object
# dtypes: float64(1), object(1)
# memory usage: 469.0+ KB

# %%
sensors_a_to_w = sc_aa[['wavelength', 'amplitude_a']]
sensors_a_to_w['amplitude_w'] = sc_aw['amplitude_w']
sensors_a_to_w.head()
# Out:
#    wavelength amplitude_a amplitude_w
# 0      1350.0      9.1792       8.357
# 1      1350.1      9.2003      8.4287
# 2      1350.2      9.1968      8.4422
# 3      1350.3      9.1028      8.4144
# 4      1350.4      9.0601      8.4034

# %%
sensors_a_to_i = sc_aa[['wavelength', 'amplitude_a']]
sensors_a_to_i['amplitude_i'] = sc_ai['amplitude_i']
sensors_a_to_i.head()
# Out:
#    wavelength amplitude_a amplitude_i
# 0      1350.0      9.1792      8.5551
# 1      1350.1      9.2003       8.675
# 2      1350.2      9.1968      8.7116
# 3      1350.3      9.1028      8.7157
# 4      1350.4      9.0601      8.6792

# %%
sensors_a_to_i.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30010 entries, 0 to 30009
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   wavelength   30010 non-null  float64
#  1   amplitude_a  30010 non-null  object
#  2   amplitude_i  30010 non-null  object
# dtypes: float64(1), object(2)
# memory usage: 703.5+ KB

# %%
sensors_a_to_w['amplitude_a'] = pd.to_numeric(sensors_a_to_w['amplitude_a'])
sensors_a_to_w['amplitude_w'] = pd.to_numeric(sensors_a_to_w['amplitude_w'])
sensors_a_to_i['amplitude_a'] = pd.to_numeric(sensors_a_to_i['amplitude_a'])
sensors_a_to_i['amplitude_i'] = pd.to_numeric(sensors_a_to_i['amplitude_i'])

# %%
fig, ax = plt.subplots(figsize=(30,10))
ax.scatter(sensors_a_to_w['wavelength'], sensors_a_to_w['amplitude_a'], label='A')
ax.scatter(sensors_a_to_w['wavelength'], sensors_a_to_w['amplitude_w'], label='W')
ax.scatter(sensors_a_to_i['wavelength'], sensors_a_to_i['amplitude_i'], label='I')
plt.legend()
plt.show()

# %% [markdown]
# **MODELS - AIR TO WATER**

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, r2_score

# %%
X_atow = sensors_a_to_w[['wavelength', 'amplitude_a']]
y_atow = sensors_a_to_w['amplitude_w']

# %%
X_atow_train, X_atow_test, y_atow_train, y_atow_test = train_test_split(X_atow, y_atow, test_size=0.2, random_state=42)
print(X_atow.shape, y_atow.shape)
print(X_atow_train.shape, y_atow_train.shape)
print(X_atow_test.shape, y_atow_test.shape)
# Out:
# (30010, 2) (30010,)
# (24008, 2) (24008,)
# (6002, 2) (6002,)

# %%
X_atow_train, X_atow_val, y_atow_train, y_atow_val = train_test_split(X_atow_train, y_atow_train, test_size=0.25, random_state=42)

# %%
print(X_atow.shape, y_atow.shape)
print(X_atow_train.shape, y_atow_train.shape)
print(X_atow_test.shape, y_atow_test.shape)
print(X_atow_val.shape, y_atow_val.shape)
# Out:
# (30010, 2) (30010,)
# (18006, 2) (18006,)
# (6002, 2) (6002,)
# (6002, 2) (6002,)

# %%
poly_atow_train = PolynomialFeatures(degree=3)
X_atow_train_poly = poly_atow_train.fit_transform(X_atow_train)

# %%
model_atow = LinearRegression()
model_atow.fit(X_atow_train_poly, y_atow_train)
# Out:
# LinearRegression()

# %%
y_atow_train_predict = model_atow.predict(X_atow_train_poly)
y_atow_train_predict
# Out:
# array([-2.27723677, -9.14162946, -6.58968331, ...,  4.87055169,
#         3.69129329, -3.22709297])

# %%
poly_atow_val = PolynomialFeatures(degree=3)
X_atow_val_poly = poly_atow_val.fit_transform(X_atow_val)

# %%
y_atow_val_predict = model_atow.predict(X_atow_val_poly)

# %%
poly_atow_test = PolynomialFeatures(degree=3)
X_atow_test_poly = poly_atow_test.fit_transform(X_atow_test)

# %%
y_atow_test_predict = model_atow.predict(X_atow_test_poly)
y_atow_test_predict
# Out:
# array([-2.78794373,  6.58148193, -0.79275971, ...,  8.00762901,
#        -9.86892641,  3.38877109])

# %% [markdown]
# **EVALUATION - AIR TO WATER**

# %%
r2_train = r2_score(y_atow_train, y_atow_train_predict)
r2_val = r2_score(y_atow_val, y_atow_val_predict)
r2_test = r2_score(y_atow_test, y_atow_test_predict)

print(f'R2 FOR TRAIN: {r2_train}')
print(f'R2 FOR VAL: {r2_val}')
print(f'R2 FOR TEST: {r2_test}')
# Out:
# R2 FOR TRAIN: 0.9901922694451616
# R2 FOR VAL: 0.9905343484512316
# R2 FOR TEST: 0.9904730759850564

# %%
MAE_train = mean_absolute_error(y_atow_train, y_atow_train_predict)
MAE_val = mean_absolute_error(y_atow_val, y_atow_val_predict)
MAE_test = mean_absolute_error(y_atow_test, y_atow_test_predict)

print(f'MAE FOR TRAIN: {MAE_train}')
print(f'MAE FOR VAL: {MAE_val}')
print(f'MAE FOR TEST: {MAE_test}')
# Out:
# MAE FOR TRAIN: 0.45531466650519214
# MAE FOR VAL: 0.44399791777858966
# MAE FOR TEST: 0.44348896324181103

# %%
MAPE_train = mean_absolute_percentage_error(y_atow_train, y_atow_train_predict)
MAPE_val = mean_absolute_percentage_error(y_atow_val, y_atow_val_predict)
MAPE_test = mean_absolute_percentage_error(y_atow_test, y_atow_test_predict)

print(f'MAPE FOR TRAIN: {MAPE_train}')
print(f'MAPE FOR VAL: {MAPE_val}')
print(f'MAPE FOR TEST: {MAPE_test}')
# Out:
# MAPE FOR TRAIN: 0.2646364519893888
# MAPE FOR VAL: 0.20164108182678217
# MAPE FOR TEST: 0.40802225029171646

# %% [markdown]
# **MODELS - AIR TO ISOPROPANOL**

# %%
X_atoi = sensors_a_to_i[['wavelength', 'amplitude_a']]
y_atoi = sensors_a_to_i['amplitude_i']

# %%
X_atoi_train, X_atoi_test, y_atoi_train, y_atoi_test = train_test_split(X_atoi, y_atoi, test_size=0.2, random_state=42)
X_atoi_train, X_atoi_val, y_atoi_train, y_atoi_val = train_test_split(X_atoi_train, y_atoi_train, test_size=0.25, random_state=42)

# %%
poly_atoi_train = PolynomialFeatures(degree=3)
X_atoi_train_poly = poly_atoi_train.fit_transform(X_atoi_train)

# %%
model_atoi = LinearRegression()
model_atoi.fit(X_atow_train_poly, y_atow_train)
y_atoi_train_predict = model_atoi.predict(X_atoi_train_poly)
y_atoi_train_predict
# Out:
# array([-2.27723677, -9.14162946, -6.58968331, ...,  4.87055169,
#         3.69129329, -3.22709297])

# %%
poly_atoi_val = PolynomialFeatures(degree=3)
X_atoi_val_poly = poly_atoi_val.fit_transform(X_atoi_val)
y_atoi_val_predict = model_atoi.predict(X_atoi_val_poly)
y_atoi_val_predict
# Out:
# array([-10.64561544,  -3.181526  , -10.17020531, ...,  -6.90807344,
#         -8.56292629,  -4.70970674])

# %%
poly_atoi_test = PolynomialFeatures(degree=3)
X_atoi_test_poly = poly_atoi_test.fit_transform(X_atoi_test)
y_atoi_test_predict = model_atoi.predict(X_atoi_test_poly)
y_atoi_test_predict
# Out:
# array([-2.78794373,  6.58148193, -0.79275971, ...,  8.00762901,
#        -9.86892641,  3.38877109])

# %% [markdown]
# **EVALUATION - AIR TO ISOPROPANOL**

# %%
r2_train2 = r2_score(y_atoi_train, y_atoi_train_predict)
r2_val2 = r2_score(y_atoi_val, y_atoi_val_predict)
r2_test2 = r2_score(y_atoi_test, y_atoi_test_predict)

print(f'R2 FOR TRAIN2: {r2_train}')
print(f'R2 FOR VAL2: {r2_val}')
print(f'R2 FOR TEST2: {r2_test}')
# Out:
# R2 FOR TRAIN2: 0.9901922694451616
# R2 FOR VAL2: 0.9905343484512316
# R2 FOR TEST2: 0.9904730759850564

# %%
MAE_train2 = mean_absolute_error(y_atoi_train, y_atoi_train_predict)
MAE_val2 = mean_absolute_error(y_atoi_val, y_atoi_val_predict)
MAE_test2 = mean_absolute_error(y_atoi_test, y_atoi_test_predict)

print(f'MAE FOR TRAIN2: {MAE_train2}')
print(f'MAE FOR VAL2: {MAE_val2}')
print(f'MAE FOR TEST2: {MAE_test2}')
# Out:
# MAE FOR TRAIN2: 0.6418018021784474
# MAE FOR VAL2: 0.6341498330820361
# MAE FOR TEST2: 0.6180029580549685

# %%
MAPE_train2 = mean_absolute_percentage_error(y_atoi_train, y_atoi_train_predict)
MAPE_val2 = mean_absolute_percentage_error(y_atoi_val, y_atoi_val_predict)
MAPE_test2 = mean_absolute_percentage_error(y_atoi_test, y_atoi_test_predict)

print(f'MAPE FOR TRAIN2: {MAPE_train2}')
print(f'MAPE FOR VAL2: {MAPE_val2}')
print(f'MAPE FOR TEST2: {MAPE_test2}')
# Out:
# MAPE FOR TRAIN2: 0.2884568528305949
# MAPE FOR VAL2: 0.41019546326736195
# MAPE FOR TEST2: 0.5506808714285291

# %% [markdown]
# **PREDICTION VISUALIATION**

# %%
theta_0 = model_atow.intercept_
theta_1 = model_atow.coef_[1]
theta_2 = model_atow.coef_[2]
theta_3 = model_atow.coef_[3]

fig, ax = plt.subplots(figsize=(20,10))
plt.scatter(X_atow['wavelength'], y_atow, label='real y')
plt.scatter(X_atow_test['wavelength'], y_atow_test_predict, label='predict y')

plt.show()

# %%
theta_0 = model_atow.intercept_
theta_1 = model_atow.coef_[1]
theta_2 = model_atow.coef_[2]
theta_3 = model_atow.coef_[3]

print(theta_0)
print(theta_1)
print(theta_2)
print(theta_3)
# Out:
# -6553.8101276884145
# 13.25020427299869
# -29.86352642818452
# -0.008885073398633203
